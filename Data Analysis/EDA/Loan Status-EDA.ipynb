# %%
import pandas as pd
df1=pd.read_csv(r'C:\Users\KCK9676\Desktop\Classes\Python\Class-13 Python\Python_Credit_Risk_XTrain.csv')

# %%
df2=pd.read_csv(r'C:\Users\KCK9676\Desktop\Classes\Python\Class-13 Python\Python_Module_Day_15.4_Credit_Risk_Validate_data_XTEST.csv')

# %%
df2.rename(columns={'outcome':'Loan_Status'},inplace=True)

# %%
df=pd.concat([df1,df2],axis=0).drop_duplicates().reset_index().drop(columns='index')

# %%
df
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001002   Male      No          0      Graduate            No
# 1    LP001003   Male     Yes          1      Graduate            No
# 2    LP001005   Male     Yes          0      Graduate           Yes
# 3    LP001006   Male     Yes          0  Not Graduate            No
# 4    LP001008   Male      No          0      Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 976  LP002971   Male     Yes         3+  Not Graduate           Yes
# 977  LP002975   Male     Yes          0      Graduate            No
# 978  LP002980   Male      No          0      Graduate            No
# 979  LP002986   Male     Yes          0      Graduate            No
# 980  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         NaN             360.0
# ...

# %%
df['Loan Status']=df.Loan_Status.map({1:'Yes', 0:'No'})

# %%
df.drop('Loan_Status',axis=1,inplace=True)

# %%
df
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001002   Male      No          0      Graduate            No
# 1    LP001003   Male     Yes          1      Graduate            No
# 2    LP001005   Male     Yes          0      Graduate           Yes
# 3    LP001006   Male     Yes          0  Not Graduate            No
# 4    LP001008   Male      No          0      Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 976  LP002971   Male     Yes         3+  Not Graduate           Yes
# 977  LP002975   Male     Yes          0      Graduate            No
# 978  LP002980   Male      No          0      Graduate            No
# 979  LP002986   Male     Yes          0      Graduate            No
# 980  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         NaN             360.0
# ...

# %%
df.index.is_unique
# Out:
# True

# %%
sns.pairplot(df,hue='Loan Status')

# %%
#Conclusions:

#1.Loan Amount and Credit history is the most useful features to identify Loan Status.
#2.Loan Amount Term and Credit history is also one of the best usedful feature to identify Loan Status.
#3.Applicant Income and Credit history can also be considered to identify Loan Status.
#4.We can find the linear lines and if else conditions to build a simple model to classify the Loan Status.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
